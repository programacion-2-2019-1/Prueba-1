# %% [markdown]
# # Programación II

# %% [markdown]
# Jupyter es un entorno virtual computacional, con el propósito de ser un entorno interactivo de ciencia de datos y computación científica que soporta varios lenguajes, como Python, Julia y R.

# %% [markdown]
# ![text](https://static.makeuseof.com/wp-content/uploads/2018/03/python-faq-670x335.jpg)

# %% [markdown]
# En este ambiente, se puede realizar una combinación elegante entre imágenes, texto, LaTeX, código y resultados. Además se pueden importar en muchos formatos, ya sea pdf, html, o incluso el formato propio del entorno: ipynb. Veamos un ejemplo:

# %% [markdown]
# ## Ecuaciónes en LaTeX
# El entorno de Jupyter y su hipertexto markdown, también soporta ecuaciónes de LaTeX:
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
q=24
w=32
print("Tenemos",q+w,"estudiantes en el curso")
# Out:
# Tenemos 56 estudiantes en el curso

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='Eje X', ylabel='Eje Y',
       title='Ejemplo')
ax.grid()

fig.savefig("test.png")
plt.show()
