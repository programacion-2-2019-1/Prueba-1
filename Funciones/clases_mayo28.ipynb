# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from clase2 import *
print('clases P-II')
# Out:
# clases P-II

# %% [markdown]
# Se crea figura1 y figura2 como **instancias** (objetos) de la clase Figura.

# %%
figura1 = Figura()
figura2 = Figura()
print('Clase creada')
# Out:
# Clase creada

# %%
figura1.rotar(3.1415/2)
figura2.rotar(-3.1415/4)
dt = .1
t = np.arange(-2*np.pi,2*np.pi,dt)
y = 2*np.sin(t)

# %%
fig, ax=plt.subplots()
ax.plot(t,y,'go-')
figura1.rotar(3.1415/2)
figura1.reset()

for i in range(len(t)-1):
    # calcular punto medio
    x_m = (t[i]+t[i+1])/2
    y_m = (y[i]+y[i+1])/2
    figura1.reset()
    figura1.ampliar(0.5,0.5)
    # calcular pendiente
    angulo = np.arctan((y[i+1]-y[i])/(t[i+1]-t[i]))
    figura1.rotar(angulo)
    figura1.mover(x_m,y_m)
    ax.plot(figura1.x,figura1.y,'ko-')
    pass
ax.grid(); ax.axis([-5,5,-3,3])
plt.show
print('Fin ok')
# Out:
# Fin ok
